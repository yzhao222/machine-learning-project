# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/MyDrive/optiver-trading-at-the-close (1)/")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, BatchNormalization,Input,Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error
import tensorflow as tf

stock_num = 200
date_num = 481
second_num = 55
training_num = 6000
epoch = 10
batch_size = 32

df = pd.read_csv("/content/drive/MyDrive/optiver-trading-at-the-close (1)/train.csv")
df = df[["stock_id", "date_id", "seconds_in_bucket", "target"]]
df.dropna(subset=["target"], inplace=True)
print(df)
# Out:
#          stock_id  date_id  seconds_in_bucket    target
# 0               0        0                  0 -3.029704
# 1               1        0                  0 -5.519986
# 2               2        0                  0 -8.389950
# 3               3        0                  0 -4.010200
# 4               4        0                  0 -7.349849
# ...           ...      ...                ...       ...
# 5237975       195      480                540  2.310276
# 5237976       196      480                540 -8.220077
# 5237977       197      480                540  1.169443
# 5237978       198      480                540 -1.540184
# 5237979       199      480                540 -6.530285
#
# [5237892 rows x 4 columns]

# %%
def generate_features(df):

    df_pivoted = df.pivot(columns='stock_id', index=['date_id', 'seconds_in_bucket'], values='target')
    return df_pivoted

df_pivoted = generate_features(df)
df_pivoted=df_pivoted.fillna(0)
df_pivoted
# Out:
# stock_id                        0          1         2         3         4    \
# date_id seconds_in_bucket
# 0       0                 -3.029704  -5.519986 -8.389950 -4.010200 -7.349849
#         10                 0.389814  -1.620054 -7.460117 -1.040101 -6.719828
#         20                 4.220009  -6.459951 -6.380081 -2.030134 -0.690222
#         30                 5.450249  -5.149841 -5.819797  1.130104 -2.589822
#         40                 3.169775  -6.750226 -0.280142 -2.350211 -4.900098
# ...                             ...        ...       ...       ...       ...
# 480     500                3.999472   2.850294 -4.450083  1.720190  1.939535
#         510                3.190041   3.169775 -5.559921  4.669428  2.139807
#         520               -0.169873   5.689859 -5.310178  5.639792  1.660585
#         530                3.110170  10.650158 -5.239844  5.229711  0.300407
#         540                0.760555  15.859604 -1.549721  3.160238  1.009703
#
# stock_id                        5         6          7         8         9    \
# date_id seconds_in_bucket
# 0       0                  6.779432 -2.499819  -1.959801 -5.970001  7.970333
#         10                 7.710457 -4.280209  -8.010268 -0.780225 -0.640154
#         20                 1.009703  2.930164 -12.069941 -4.119873 -3.250241
#         30                -3.089905  0.560284  -6.909967 -1.090169 -6.759763
#         40                -2.070069  2.199411  -1.209974 -3.100038 -8.199811
# ...                             ...       ...        ...       ...       ...
# 480     500               -4.569888 -0.630021  -1.729727 -0.680089  3.540516
#         510                1.679659 -0.360012  -3.240108  2.609491  1.679659
#         520                2.110004 -1.000166  -4.529953  5.409718  0.350475
#         530               -2.030134 -1.180172  -1.310110  3.240108  0.220537
#         540                2.340078  1.410246  -1.260042  3.679991 -1.609922
#
# stock_id                   ...       190        191        192       193  \
# date_id seconds_in_bucket  ...
# 0       0                  ...  6.370544  11.940002 -11.529922 -6.489754
#         10                 ...  4.210472   2.599955 -15.599728 -1.749992
#         20                 ...  5.379915  -5.970001 -12.710094  2.160072
#         30                 ... -3.269911   1.300573 -16.660095  4.090071
#         40                 ... -2.009869  -0.969768  -9.229779  5.700588
# ...                        ...       ...        ...        ...       ...
# 480     500                ... -4.730225  -7.420182   2.959967 -2.359748
#         510                ... -3.340244  -3.479719   1.419783 -1.069903
#         520                ... -1.549721  -1.289845  -0.140071 -1.929998
#         530                ... -1.440048  -0.299811  -2.120137 -1.350045
#         540                ... -0.470281   0.799894  -1.729727 -3.880262
#
# stock_id                         194       195       196       197       198  \
# date_id seconds_in_bucket
# 0       0                   3.999472 -0.690222 -0.810027 -8.440018 -0.510216
#         10                 -9.030104 -1.320243 -3.259778 -4.410148 -1.419783
#         20                 -9.999871  5.890131 -0.029802 -6.819964  2.599955
#         30                 -9.340048  7.020235  1.549721  1.690388  3.010035
#         40                -11.489987  4.500151 -1.350045 -1.929998  4.669428
# ...                              ...       ...       ...       ...       ...
# 480     500                -0.650287  3.190041 -1.659989 -0.690222 -2.700090
#         510                 2.319813  3.770590 -3.039837 -3.299713 -2.070069
#         520                 4.609823  1.449585 -6.319881 -1.999736 -2.239943
#         530                 3.110170  4.019737 -7.349849 -3.259778 -3.160238
#         540                 4.839897  2.310276 -8.220077  1.169443 -1.540184
#
# stock_id                        199
# date_id seconds_in_bucket
# 0       0                  0.000000
#         10                 0.000000
#         20                 0.000000
#         30                 0.000000
#         40                 0.000000
# ...                             ...
# 480     500               -7.209778
#         510               -9.750128
#         520                3.629923
#         530                4.760027
#         540               -6.530285
#
# [26455 rows x 200 columns]

# %%
def build_model(dropout=0.5):
    model = Sequential()
    model.add(Input(shape=(55, 200)))
    model.add(LSTM(300, activation="tanh", return_sequences=False))
    model.add(Dropout(dropout))
    model.add(Dense(200))
    model.compile(loss='mae',
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
    return model

# %%
def windowed_dataset(dataset, shuffle=True):
    dataset = tf.data.Dataset.from_tensor_slices(dataset)
    dataset = dataset.window(55 + 1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(55 + 1))
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))
    if shuffle:
      dataset = dataset.shuffle(10000)
    dataset = dataset.batch(64).prefetch(1)
    return dataset

# %%
split_index = int(len(df_pivoted) * 0.8)
train_df = df_pivoted.iloc[:split_index]
valid_df = df_pivoted.iloc[split_index:]
scaler=StandardScaler()
train_df = scaler.fit_transform(train_df)
valid_df = scaler.transform(valid_df)
train_dataset = windowed_dataset(train_df)
valid_dataset = windowed_dataset(valid_df, shuffle=False)
model = build_model()
history = model.fit(train_dataset,validation_data=valid_dataset,epochs=120,batch_size=64,verbose=True)


y_pred = model.predict(valid_dataset)
y_pred = scaler.inverse_transform(y_pred)
y_true = valid_df[55:]
mae = mean_absolute_error(y_true, y_pred)
print(f"MAE score: {mae}")

    ## Plots ##
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/120
# 330/330 [==============================] - 16s 17ms/step - loss: 0.6752 - val_loss: 0.5919
# Epoch 2/120
# 330/330 [==============================] - 7s 15ms/step - loss: 0.6154 - val_loss: 0.5515
# Epoch 3/120
# 330/330 [==============================] - 7s 14ms/step - loss: 0.5997 - val_loss: 0.5400
# Epoch 4/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5934 - val_loss: 0.5366
# Epoch 5/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5904 - val_loss: 0.5337
# Epoch 6/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5881 - val_loss: 0.5317
# Epoch 7/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5855 - val_loss: 0.5316
# Epoch 8/120
# 330/330 [==============================] - 7s 14ms/step - loss: 0.5841 - val_loss: 0.5314
# Epoch 9/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5825 - val_loss: 0.5317
# Epoch 10/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5814 - val_loss: 0.5323
# Epoch 11/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5802 - val_loss: 0.5335
# Epoch 12/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5788 - val_loss: 0.5334
# Epoch 13/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5777 - val_loss: 0.5344
# Epoch 14/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5766 - val_loss: 0.5342
# Epoch 15/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5756 - val_loss: 0.5342
# Epoch 16/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5749 - val_loss: 0.5361
# Epoch 17/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5742 - val_loss: 0.5352
# Epoch 18/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5734 - val_loss: 0.5366
# Epoch 19/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5726 - val_loss: 0.5364
# Epoch 20/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5720 - val_loss: 0.5375
# Epoch 21/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5714 - val_loss: 0.5369
# Epoch 22/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5708 - val_loss: 0.5377
# Epoch 23/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5704 - val_loss: 0.5375
# Epoch 24/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5700 - val_loss: 0.5383
# Epoch 25/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5697 - val_loss: 0.5388
# Epoch 26/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5691 - val_loss: 0.5388
# Epoch 27/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5691 - val_loss: 0.5394
# Epoch 28/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5686 - val_loss: 0.5397
# Epoch 29/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5684 - val_loss: 0.5398
# Epoch 30/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5678 - val_loss: 0.5399
# Epoch 31/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5676 - val_loss: 0.5410
# Epoch 32/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5676 - val_loss: 0.5411
# Epoch 33/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5669 - val_loss: 0.5417
# Epoch 34/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5670 - val_loss: 0.5416
# Epoch 35/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5664 - val_loss: 0.5417
# Epoch 36/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5663 - val_loss: 0.5415
# Epoch 37/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5657 - val_loss: 0.5421
# Epoch 38/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5659 - val_loss: 0.5422
# Epoch 39/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5658 - val_loss: 0.5423
# Epoch 40/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5655 - val_loss: 0.5428
# Epoch 41/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5653 - val_loss: 0.5433
# Epoch 42/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5650 - val_loss: 0.5432
# Epoch 43/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5650 - val_loss: 0.5441
# Epoch 44/120
# 330/330 [==============================] - 7s 14ms/step - loss: 0.5647 - val_loss: 0.5441
# Epoch 45/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5644 - val_loss: 0.5441
# Epoch 46/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5643 - val_loss: 0.5436
# Epoch 47/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5641 - val_loss: 0.5447
# Epoch 48/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5641 - val_loss: 0.5447
# Epoch 49/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5638 - val_loss: 0.5451
# Epoch 50/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5637 - val_loss: 0.5448
# Epoch 51/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5638 - val_loss: 0.5454
# Epoch 52/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5634 - val_loss: 0.5455
# Epoch 53/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5630 - val_loss: 0.5461
# Epoch 54/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5631 - val_loss: 0.5459
# Epoch 55/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5633 - val_loss: 0.5462
# Epoch 56/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5631 - val_loss: 0.5461
# Epoch 57/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5627 - val_loss: 0.5462
# Epoch 58/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5624 - val_loss: 0.5465
# Epoch 59/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5625 - val_loss: 0.5467
# Epoch 60/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5623 - val_loss: 0.5468
# Epoch 61/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5623 - val_loss: 0.5469
# Epoch 62/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5619 - val_loss: 0.5469
# Epoch 63/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5620 - val_loss: 0.5476
# Epoch 64/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5619 - val_loss: 0.5473
# Epoch 65/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5618 - val_loss: 0.5472
# Epoch 66/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5616 - val_loss: 0.5469
# Epoch 67/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5615 - val_loss: 0.5477
# Epoch 68/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5614 - val_loss: 0.5481
# Epoch 69/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5611 - val_loss: 0.5479
# Epoch 70/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5610 - val_loss: 0.5485
# Epoch 71/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5609 - val_loss: 0.5488
# Epoch 72/120
# 330/330 [==============================] - 7s 14ms/step - loss: 0.5611 - val_loss: 0.5491
# Epoch 73/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5610 - val_loss: 0.5491
# Epoch 74/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5606 - val_loss: 0.5489
# Epoch 75/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5604 - val_loss: 0.5491
# Epoch 76/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5607 - val_loss: 0.5495
# Epoch 77/120
# 330/330 [==============================] - 7s 14ms/step - loss: 0.5604 - val_loss: 0.5492
# Epoch 78/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5603 - val_loss: 0.5497
# Epoch 79/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5606 - val_loss: 0.5498
# Epoch 80/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5600 - val_loss: 0.5499
# Epoch 81/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5600 - val_loss: 0.5497
# Epoch 82/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5603 - val_loss: 0.5502
# Epoch 83/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5601 - val_loss: 0.5505
# Epoch 84/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5601 - val_loss: 0.5502
# Epoch 85/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5598 - val_loss: 0.5504
# Epoch 86/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5597 - val_loss: 0.5506
# Epoch 87/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5598 - val_loss: 0.5512
# Epoch 88/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5597 - val_loss: 0.5509
# Epoch 89/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5594 - val_loss: 0.5512
# Epoch 90/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5594 - val_loss: 0.5512
# Epoch 91/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5594 - val_loss: 0.5517
# Epoch 92/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5595 - val_loss: 0.5511
# Epoch 93/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5589 - val_loss: 0.5512
# Epoch 94/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5590 - val_loss: 0.5515
# Epoch 95/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5588 - val_loss: 0.5517
# Epoch 96/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5590 - val_loss: 0.5518
# Epoch 97/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5590 - val_loss: 0.5514
# Epoch 98/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5590 - val_loss: 0.5518
# Epoch 99/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5586 - val_loss: 0.5519
# Epoch 100/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5588 - val_loss: 0.5519
# Epoch 101/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5587 - val_loss: 0.5523
# Epoch 102/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5583 - val_loss: 0.5528
# Epoch 103/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5583 - val_loss: 0.5524
# Epoch 104/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5582 - val_loss: 0.5524
# Epoch 105/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5584 - val_loss: 0.5523
# Epoch 106/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5581 - val_loss: 0.5530
# Epoch 107/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5583 - val_loss: 0.5531
# Epoch 108/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5582 - val_loss: 0.5530
# Epoch 109/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5581 - val_loss: 0.5530
# Epoch 110/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5582 - val_loss: 0.5533
# Epoch 111/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5581 - val_loss: 0.5531
# Epoch 112/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5577 - val_loss: 0.5532
# Epoch 113/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5579 - val_loss: 0.5534
# Epoch 114/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5580 - val_loss: 0.5535
# Epoch 115/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5577 - val_loss: 0.5534
# Epoch 116/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5580 - val_loss: 0.5538
# Epoch 117/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5579 - val_loss: 0.5540
# Epoch 118/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5576 - val_loss: 0.5541
# Epoch 119/120
# 330/330 [==============================] - 6s 13ms/step - loss: 0.5574 - val_loss: 0.5541
# Epoch 120/120
# 330/330 [==============================] - 6s 14ms/step - loss: 0.5575 - val_loss: 0.5543
# 82/82 [==============================] - 1s 9ms/step
# MAE score: 2.3904283538831974

# %%
import optiver2023
env = optiver2023.make_env()
iter_test = env.iter_test()
counter = 0
for (test, revealed_targets, sample_prediction) in iter_test:
    if counter == 0:
        print(test.head(3))
        print(revealed_targets.head(3))
        print(sample_prediction.head(3))
    sample_prediction['target'] = 0
    env.predict(sample_prediction)
    counter += 1
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0         0      478                  0      3753451.43
# 1         1      478                  0       985977.11
# 2         2      478                  0       599128.74
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                       -1         0.999875   11548975.43        NaN
# 1                       -1         1.000245    3850033.97        NaN
# 2                        1         1.000584    4359198.25        NaN
#
#    near_price  bid_price  bid_size  ask_price  ask_size  wap   row_id  \
# 0         NaN   0.999875  22940.00   1.000050   9177.60  1.0  478_0_0
# 1         NaN   0.999940   1967.90   1.000601  19692.00  1.0  478_0_1
# 2         NaN   0.999918   4488.22   1.000636  34955.12  1.0  478_0_2
#
#    currently_scored
# 0             False
# 1             False
# 2             False
#    stock_id  date_id  seconds_in_bucket  revealed_target  revealed_date_id  \
# 0         0      478                  0        -2.310276               477
# 1         1      478                  0       -12.850165               477
# 2         2      478                  0        -0.439882               477
#
#    revealed_time_id
# 0             26235
# 1             26235
# 2             26235
#     row_id  target
# 0  478_0_0     0.0
# 1  478_0_1     0.0
# 2  478_0_2     0.0
